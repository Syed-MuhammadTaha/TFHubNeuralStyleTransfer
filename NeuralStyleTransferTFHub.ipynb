# %% [markdown]
# <a href="https://colab.research.google.com/github/Syed-MuhammadTaha/TFHubNeuralStyleTransfer/blob/main/NeuralStyleTransferTFHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow_hub as hub
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
model = hub.load('https://www.kaggle.com/models/google/arbitrary-image-stylization-v1/TensorFlow1/256/2')

# %%
def load_image(img_path):
  img = tf.io.read_file(img_path)
  img = tf.image.decode_image(img, channels=3)
  img = tf.image.convert_image_dtype(img, tf.float32)
  img = tf.expand_dims(img, axis=0)
  img = tf.image.resize(img, (256, 256))
  return img

# %%
content = load_image('content.jpg')
style = load_image('style.jpg')

# %%
content.shape
# Out:
# TensorShape([1, 256, 256, 3])

# %%
stylized_image = model(tf.constant(content), tf.constant(style))

# %%
stylized_image
# Out:
# <tf.Tensor: shape=(1, 256, 256, 3), dtype=float32, numpy=
# array([[[[0.26892632, 0.46990967, 0.843038  ],
#          [0.26198426, 0.4866127 , 0.82367164],
#          [0.36063555, 0.5801442 , 0.8920866 ],
#          ...,
#          [0.37426743, 0.5225133 , 0.84043384],
#          [0.48475772, 0.6303984 , 0.9092637 ],
#          [0.27380806, 0.43891713, 0.7877116 ]],
#
#         [[0.311026  , 0.52354956, 0.85509783],
#          [0.28847915, 0.5115474 , 0.8354628 ],
#          [0.30160365, 0.5190023 , 0.8623854 ],
#          ...,
#          [0.5314878 , 0.6637998 , 0.9028368 ],
#          [0.62804776, 0.71597993, 0.9396699 ],
#          [0.43261704, 0.5725619 , 0.86500776]],
#
#         [[0.24315174, 0.44704115, 0.7854404 ],
#          [0.2137678 , 0.42424932, 0.7437545 ],
#          [0.21827474, 0.4258579 , 0.78541917],
#          ...,
#          [0.38031182, 0.52831954, 0.817591  ],
#          [0.52695405, 0.63860714, 0.90648544],
#          [0.37880725, 0.53369415, 0.81656617]],
#
# ...

# %%
plt.imshow(np.squeeze(stylized_image))
